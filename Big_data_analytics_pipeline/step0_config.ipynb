# %%
# 00_config — Global Configuration for Influencer Analytics Pipeline

from pyspark.sql import functions as F

# --- Catalog Setup ---
CATALOG = "influencer"

def tbl(name: str) -> str:
    """Helper to reference tables inside the Influencer catalog"""
    return f"{CATALOG}.{name}"

# --- Data Paths ---
# Workspace CSV path (where your uploaded dataset is)
WORKSPACE_CSV = "/Workspace/Users/ragutudeepika68730@gmail.com/Big_data_analytics_pipeline/Influencers_dataset.csv"

# UC Volume path (destination for safe ingestion)
VOLUME_CSV = "/Volumes/influencer/default/Influencers_dataset.csv"

# --- Debug info ---
print("✅ Configuration Loaded:")
print(f"CATALOG: {CATALOG}")
print(f"WORKSPACE_CSV: {WORKSPACE_CSV}")
print(f"VOLUME_CSV: {VOLUME_CSV}")
# Out:
# ✅ Configuration Loaded:
# CATALOG: influencer
# WORKSPACE_CSV: /Workspace/Users/ragutudeepika68730@gmail.com/Big_data_analytics_pipeline/Influencers_dataset.csv
# VOLUME_CSV: /Volumes/influencer/default/Influencers_dataset.csv
